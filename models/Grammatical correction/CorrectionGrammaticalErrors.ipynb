# %%
# !pip3 install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.1.2)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.46)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.3.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.8.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.6.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)

# %%
# !pip3 install pip==20.1.1
# Out:
# Requirement already satisfied: pip==20.1.1 in /usr/local/lib/python3.7/dist-packages (20.1.1)

# %%
# !pip3 install -U git+https://github.com/PrithivirajDamodaran/Gramformer.git
# Out:
# Collecting git+https://github.com/PrithivirajDamodaran/Gramformer.git
#   Cloning https://github.com/PrithivirajDamodaran/Gramformer.git to /tmp/pip-req-build-z8w4nw9h
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Gramformer.git /tmp/pip-req-build-z8w4nw9h
# Requirement already satisfied, skipping upgrade: transformers in /usr/local/lib/python3.7/dist-packages (from gramformer==1.0) (4.12.4)
# Requirement already satisfied, skipping upgrade: sentencepiece==0.1.95 in /usr/local/lib/python3.7/dist-packages (from gramformer==1.0) (0.1.95)
# Requirement already satisfied, skipping upgrade: python-Levenshtein==0.12.2 in /usr/local/lib/python3.7/dist-packages (from gramformer==1.0) (0.12.2)
# Requirement already satisfied, skipping upgrade: fuzzywuzzy==0.18.0 in /usr/local/lib/python3.7/dist-packages (from gramformer==1.0) (0.18.0)
# Requirement already satisfied, skipping upgrade: tokenizers==0.10.2 in /usr/local/lib/python3.7/dist-packages (from gramformer==1.0) (0.10.2)
# Requirement already satisfied, skipping upgrade: fsspec==2021.5.0 in /usr/local/lib/python3.7/dist-packages (from gramformer==1.0) (2021.5.0)
# Requirement already satisfied, skipping upgrade: lm-scorer==0.4.2 in /usr/local/lib/python3.7/dist-packages (from gramformer==1.0) (0.4.2)
# Requirement already satisfied, skipping upgrade: errant in /usr/local/lib/python3.7/dist-packages (from gramformer==1.0) (2.3.0)
# Requirement already satisfied, skipping upgrade: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (4.62.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (21.2)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (3.3.2)
# Requirement already satisfied, skipping upgrade: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (0.1.2)
# Requirement already satisfied, skipping upgrade: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (6.0)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (2.23.0)
# Requirement already satisfied, skipping upgrade: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (0.0.46)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (4.8.2)
# Requirement already satisfied, skipping upgrade: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->gramformer==1.0) (2019.12.20)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/dist-packages (from python-Levenshtein==0.12.2->gramformer==1.0) (57.4.0)
# Requirement already satisfied, skipping upgrade: torch<2.0.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from lm-scorer==0.4.2->gramformer==1.0) (1.5.1)
# Requirement already satisfied, skipping upgrade: pip>=20.0.0 in /usr/local/lib/python3.7/dist-packages (from lm-scorer==0.4.2->gramformer==1.0) (20.1.1)
# Requirement already satisfied, skipping upgrade: spacy<3,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from errant->gramformer==1.0) (2.2.4)
# Requirement already satisfied, skipping upgrade: pyparsing<3,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->gramformer==1.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers->gramformer==1.0) (3.10.0.2)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->gramformer==1.0) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->gramformer==1.0) (2021.10.8)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->gramformer==1.0) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->gramformer==1.0) (3.0.4)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->gramformer==1.0) (1.15.0)
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->gramformer==1.0) (1.1.0)
# Requirement already satisfied, skipping upgrade: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->gramformer==1.0) (7.1.2)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers->gramformer==1.0) (3.6.0)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.7/dist-packages (from torch<2.0.0,>=1.4.0->lm-scorer==0.4.2->gramformer==1.0) (0.16.0)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (3.0.6)
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (0.4.1)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (1.0.5)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (2.0.6)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (0.8.2)
# Requirement already satisfied, skipping upgrade: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (7.4.0)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (1.0.0)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (1.0.6)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3,>=2.2.0->errant->gramformer==1.0) (1.1.3)
# Building wheels for collected packages: gramformer
#   Building wheel for gramformer (setup.py) ... done
#   Created wheel for gramformer: filename=gramformer-1.0-py3-none-any.whl size=4501 sha256=0dad85daf00570bbd87d5433f99263a4347ab6a46c123077ab907397759b6055
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f2hkbdyr/wheels/c1/f6/04/a7ceda8a8c1d494a3523957d61eb6dfe428568b1af0b9d508c
# Successfully built gramformer
# Installing collected packages: gramformer
#   Attempting uninstall: gramformer
#     Found existing installation: gramformer 1.0
#     Uninstalling gramformer-1.0:
#       Successfully uninstalled gramformer-1.0
# Successfully installed gramformer-1.0

# %%
from gramformer import Gramformer
Gramformer
# Out:
# gramformer.gramformer.Gramformer

# %%
import torch
# !pip install torch==1.5.1 torchvision==0.6.1
# Out:
# Requirement already satisfied: torch==1.5.1 in /usr/local/lib/python3.7/dist-packages (1.5.1)
# Requirement already satisfied: torchvision==0.6.1 in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.5.1) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.5.1) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.6.1) (7.1.2)

# %%
gf = Gramformer(models = 1, use_gpu=False) # 1=corrector, 2=detector
# Out:
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# [Gramformer] Grammar error correct/highlight model loaded..

# %%
import nltk.data
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
fp = open("sample_data/Test_text.txt")
data = fp.read()
sentences = tokenizer.tokenize(data)
sentences
# Out:
# ['With all the myriad methods of messaging available to us online and on our mobile phones, sometimes its easy to forget that some older methods of SMS still exist.',
#  'Likes the pneumatic tubes in mailrooms from days of old, the pneumatic tube ofi texting is sending an SMS via e-mail.',
#  "If you're ever in as pinch and withouts you phone for whatever reason, here is a guide on sending a text message via e-mail.",
#  'This guide will walks your through a few diferent method too sends a text from you email.']

# %%
print ('\n-----\n'.join(tokenizer.tokenize(data)))
# Out:
# With all the myriad methods of messaging available to us online and on our mobile phones, sometimes its easy to forget that some older methods of SMS still exist.
# -----
# Likes the pneumatic tubes in mailrooms from days of old, the pneumatic tube ofi texting is sending an SMS via e-mail.
# -----
# If you're ever in as pinch and withouts you phone for whatever reason, here is a guide on sending a text message via e-mail.
# -----
# This guide will walks your through a few diferent method too sends a text from you email.

# %%
list_sent=[]
for influent_sentence in sentences:
    corrected_sentences = gf.correct(influent_sentence, max_candidates=1)
    list_sent += corrected_sentences
    print("[Input] ", influent_sentence)
    for corrected_sentence in corrected_sentences:
      print("[Correction] ",corrected_sentence)
    print("-" *100)
# Out:
# [Input]  With all the myriad methods of messaging available to us online and on our mobile phones, sometimes its easy to forget that some older methods of SMS still exist.
# [Correction]  ('With all the myriad methods of messaging available to us online and on our mobile phones, sometimes it is easy to forget that some older methods of SMS still exist.', -111.7161636352539)
# ----------------------------------------------------------------------------------------------------
# [Input]  Likes the pneumatic tubes in mailrooms from days of old, the pneumatic tube ofi texting is sending an SMS via e-mail.
# [Correction]  ('Like the pneumatic tubes in mailrooms from days of old, the pneumatic tube for texting is sending an SMS via e-mail.', -127.98466491699219)
# ----------------------------------------------------------------------------------------------------
# [Input]  If you're ever in as pinch and withouts you phone for whatever reason, here is a guide on sending a text message via e-mail.
# [Correction]  ("If you're ever in a pinch or without your phone for whatever reason, here is a guide on sending a text message via e-mail.", -85.1856689453125)
# ----------------------------------------------------------------------------------------------------
# [Input]  This guide will walks your through a few diferent method too sends a text from you email.
# [Correction]  ('This guide will walk you through a few different methods to send a text to your email.', -56.65046691894531)
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Reconstruct the corrected text

# %%
corrected_text= ""
for t in list_sent:
  corrected_text = corrected_text +" "+t[0]

corrected_text
# Out:
# " With all the myriad methods of messaging available to us online and on our mobile phones, sometimes it is easy to forget that some older methods of SMS still exist. Like the pneumatic tubes in mailrooms from days of old, the pneumatic tube for texting is sending an SMS via e-mail. If you're ever in a pinch or without your phone for whatever reason, here is a guide on sending a text message via e-mail. This guide will walk you through a few different methods to send a text to your email."
